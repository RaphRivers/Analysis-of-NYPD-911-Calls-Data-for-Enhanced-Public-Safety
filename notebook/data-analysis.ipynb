# %% [markdown]
# # NYPD 911 Calls for Service EDA Project

# %% [markdown]
# Data Source: [Data.gov](https://catalog.data.gov/dataset/nypd-calls-for-service) a non-federal dataset for public use.
#
# License: City of New York - NYC.gov [Terms of Use](https://www.nyc.gov/home/terms-of-use.page)

# %% [markdown]
# ## Data Collection and Setup

# %% [markdown]
# Import required libraries

# %%
import numpy as np
import pandas as pd
import requests 
import json
import seaborn as sns
# %matplotlib inline
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-dpmq4ety because the default path (/home/jupyter-raphrivers/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# Read in the dataset csv file as a dataframe called df

# %%
url = "https://data.cityofnewyork.us/resource/n2zq-pubd.json"
nypdData = requests.get(url).json()
## content = json.dumps(nypdData, indent = 4, sort_keys=True)
## print(content)

# %%
df = pd.DataFrame(nypdData)

# %%
df.head()
# Out:
#   cad_evnt_id              create_date            incident_date incident_time  \
# 0    91250176  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:24:39
# 1    91250180  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:24:47
# 2    91250681  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:55:56
# 3    91250683  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:55:59
# 4    91250700  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:57:08
#
#   nypd_pct_cd   boro_nm             patrl_boro_nm geo_cd_x geo_cd_y  \
# 0          67  BROOKLYN   PATROL BORO BKLYN SOUTH  1001878   175994
# 1          75  BROOKLYN   PATROL BORO BKLYN NORTH  1017204   180778
# 2         114    QUEENS  PATROL BORO QUEENS NORTH  1008573   217117
# 3          66  BROOKLYN   PATROL BORO BKLYN SOUTH   993234   161780
# 4         115    QUEENS  PATROL BORO QUEENS NORTH  1014264   211852
#
#   radio_code                      typ_desc cip_jobs                   add_ts  \
# 0        53I      VEHICLE ACCIDENT: INJURY  Non CIP  2023-01-01T01:08:21.000
# 1       11C4   ALARMS: COMMERCIAL/BURGLARY  Non CIP  2023-01-01T00:38:00.000
# 2       11R4  ALARMS: RESIDENTIAL/BURGLARY  Non CIP  2023-01-01T00:01:26.000
# 3       11R4  ALARMS: RESIDENTIAL/BURGLARY  Non CIP  2023-01-01T00:01:34.000
# 4       11C4   ALARMS: COMMERCIAL/BURGLARY  Non CIP  2023-01-01T00:01:29.000
#
#                    disp_ts                closng_ts            latitude  \
# 0  2023-01-01T01:09:57.000  2023-01-01T01:57:44.000  40.649730200000079
# 1  2023-01-01T00:38:34.000  2023-01-01T01:45:21.000  40.662817455000038
# 2  2023-01-01T00:06:18.000  2023-01-01T00:06:27.000  40.762587226000051
# 3  2023-01-01T00:37:14.000  2023-01-01T01:21:14.000  40.610728753000046
# 4  2023-01-01T00:14:28.000  2023-01-01T01:24:22.000  40.748118661000035
#
#              longitude                arrivd_ts
# 0  -73.936474789999977                      NaN
# 1  -73.881220610999947  2023-01-01T00:44:33.000
# 2  -73.912199256999941                      NaN
# 3  -73.967644395999969  2023-01-01T01:09:32.000
# 4  -73.891679164999971  2023-01-01T00:21:59.000

# %% [markdown]
# Check the info() of the df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cad_evnt_id    1000 non-null   object
#  1   create_date    1000 non-null   object
#  2   incident_date  1000 non-null   object
#  3   incident_time  1000 non-null   object
#  4   nypd_pct_cd    1000 non-null   object
#  5   boro_nm        1000 non-null   object
#  6   patrl_boro_nm  1000 non-null   object
#  7   geo_cd_x       1000 non-null   object
#  8   geo_cd_y       1000 non-null   object
#  9   radio_code     1000 non-null   object
#  10  typ_desc       1000 non-null   object
#  11  cip_jobs       1000 non-null   object
#  12  add_ts         1000 non-null   object
#  13  disp_ts        1000 non-null   object
#  14  closng_ts      1000 non-null   object
#  15  latitude       1000 non-null   object
#  16  longitude      1000 non-null   object
#  17  arrivd_ts      735 non-null    object
# dtypes: object(18)
# memory usage: 140.8+ KB

# %% [markdown]
# Check the head of df

# %%
df.head()
# Out:
#   cad_evnt_id              create_date            incident_date incident_time  \
# 0    91250176  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:24:39
# 1    91250180  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:24:47
# 2    91250681  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:55:56
# 3    91250683  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:55:59
# 4    91250700  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000      23:57:08
#
#   nypd_pct_cd   boro_nm             patrl_boro_nm geo_cd_x geo_cd_y  \
# 0          67  BROOKLYN   PATROL BORO BKLYN SOUTH  1001878   175994
# 1          75  BROOKLYN   PATROL BORO BKLYN NORTH  1017204   180778
# 2         114    QUEENS  PATROL BORO QUEENS NORTH  1008573   217117
# 3          66  BROOKLYN   PATROL BORO BKLYN SOUTH   993234   161780
# 4         115    QUEENS  PATROL BORO QUEENS NORTH  1014264   211852
#
#   radio_code                      typ_desc cip_jobs                   add_ts  \
# 0        53I      VEHICLE ACCIDENT: INJURY  Non CIP  2023-01-01T01:08:21.000
# 1       11C4   ALARMS: COMMERCIAL/BURGLARY  Non CIP  2023-01-01T00:38:00.000
# 2       11R4  ALARMS: RESIDENTIAL/BURGLARY  Non CIP  2023-01-01T00:01:26.000
# 3       11R4  ALARMS: RESIDENTIAL/BURGLARY  Non CIP  2023-01-01T00:01:34.000
# 4       11C4   ALARMS: COMMERCIAL/BURGLARY  Non CIP  2023-01-01T00:01:29.000
#
#                    disp_ts                closng_ts            latitude  \
# 0  2023-01-01T01:09:57.000  2023-01-01T01:57:44.000  40.649730200000079
# 1  2023-01-01T00:38:34.000  2023-01-01T01:45:21.000  40.662817455000038
# 2  2023-01-01T00:06:18.000  2023-01-01T00:06:27.000  40.762587226000051
# 3  2023-01-01T00:37:14.000  2023-01-01T01:21:14.000  40.610728753000046
# 4  2023-01-01T00:14:28.000  2023-01-01T01:24:22.000  40.748118661000035
#
#              longitude                arrivd_ts
# 0  -73.936474789999977                      NaN
# 1  -73.881220610999947  2023-01-01T00:44:33.000
# 2  -73.912199256999941                      NaN
# 3  -73.967644395999969  2023-01-01T01:09:32.000
# 4  -73.891679164999971  2023-01-01T00:21:59.000

# %%
# Drop empty null cells 
df.dropna()
# Out:
#     cad_evnt_id              create_date            incident_date  \
# 1      91250180  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000
# 3      91250683  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000
# 4      91250700  2023-01-01T00:00:00.000  2022-12-31T00:00:00.000
# 9      91250748  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# 10     91250749  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# ..          ...                      ...                      ...
# 995    91251959  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# 996    91251960  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# 997    91251963  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# 998    91251965  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
# 999    91251968  2023-01-01T00:00:00.000  2023-01-01T00:00:00.000
#
#     incident_time nypd_pct_cd        boro_nm              patrl_boro_nm  \
# 1        23:24:47          75       BROOKLYN    PATROL BORO BKLYN NORTH
# 3        23:55:59          66       BROOKLYN    PATROL BORO BKLYN SOUTH
# 4        23:57:08         115         QUEENS   PATROL BORO QUEENS NORTH
# 9        00:00:40          41          BRONX          PATROL BORO BRONX
# 10       00:00:42          24      MANHATTAN      PATROL BORO MAN NORTH
# ..            ...         ...            ...                        ...
# 995      01:04:44         100         QUEENS   PATROL BORO QUEENS SOUTH
# 996      01:04:46          90       BROOKLYN    PATROL BORO BKLYN NORTH
# 997      01:04:52          42          BRONX          PATROL BORO BRONX
# 998      01:04:54          79       BROOKLYN    PATROL BORO BKLYN NORTH
# 999      01:05:01         122  STATEN ISLAND  PATROL BORO STATEN ISLAND
#
#     geo_cd_x geo_cd_y radio_code  \
# 1    1017204   180778       11C4
# 3     993234   161780       11R4
# 4    1014264   211852       11C4
# 9    1013880   240034        75S
# 10    991834   228448       50P1
# ..       ...      ...        ...
# 995  1027029   149833       68Q1
# 996   995351   199828       10P2
# 997  1012880   241536       10P2
# 998   997880   192557        75S
# 999   948588   149069       68Q1
#
#                                               typ_desc cip_jobs  \
# 1                          ALARMS: COMMERCIAL/BURGLARY  Non CIP
# 3                         ALARMS: RESIDENTIAL/BURGLARY  Non CIP
# 4                          ALARMS: COMMERCIAL/BURGLARY  Non CIP
# 9       STATION INSPECTION BY TRANSIT BUREAU PERSONNEL  Non CIP
# 10                           DISORDERLY: PERSON/INSIDE  Non CIP
# ..                                                 ...      ...
# 995                      SEE COMPLAINANT: OTHER/INSIDE  Non CIP
# 996  INVESTIGATE/POSSIBLE CRIME: SUSP PERSON/OUTSID...  Non CIP
# 997  INVESTIGATE/POSSIBLE CRIME: SUSP PERSON/OUTSID...  Non CIP
# 998     STATION INSPECTION BY TRANSIT BUREAU PERSONNEL  Non CIP
# 999                      SEE COMPLAINANT: OTHER/INSIDE  Non CIP
#
#                       add_ts                  disp_ts  \
# 1    2023-01-01T00:38:00.000  2023-01-01T00:38:34.000
# 3    2023-01-01T00:01:34.000  2023-01-01T00:37:14.000
# 4    2023-01-01T00:01:29.000  2023-01-01T00:14:28.000
# 9    2023-01-01T00:00:40.000  2023-01-01T00:00:40.000
# 10   2023-01-01T00:00:42.000  2023-01-01T00:09:54.000
# ..                       ...                      ...
# 995  2023-01-01T01:04:44.000  2023-01-01T01:04:45.000
# 996  2023-01-01T01:04:46.000  2023-01-01T01:04:46.000
# 997  2023-01-01T01:04:52.000  2023-01-01T01:04:52.000
# 998  2023-01-01T01:04:54.000  2023-01-01T01:04:54.000
# 999  2023-01-01T01:05:01.000  2023-01-01T01:05:01.000
#
#                    closng_ts            latitude            longitude  \
# 1    2023-01-01T01:45:21.000  40.662817455000038  -73.881220610999947
# 3    2023-01-01T01:21:14.000  40.610728753000046  -73.967644395999969
# 4    2023-01-01T01:24:22.000  40.748118661000035  -73.891679164999971
# 9    2023-01-01T00:24:04.000  40.825471963000041  -73.892940736999947
# 10   2023-01-01T00:17:38.000  40.793718040000044  -73.972611609999944
# ..                       ...                 ...                  ...
# 995  2023-01-01T01:26:50.000  40.577837979000037  -73.846003101999941
# 996  2023-01-01T01:09:12.000  40.715159693000032  -73.959957107999969
# 997  2023-01-01T02:49:14.000  40.829597820000060  -73.896547577999968
# 998  2023-01-01T01:16:07.000  40.695198976000029  -73.950849031999951
# 999  2023-01-01T02:09:48.000  40.575772428000050  -74.128375591999941
#
#                    arrivd_ts
# 1    2023-01-01T00:44:33.000
# 3    2023-01-01T01:09:32.000
# 4    2023-01-01T00:21:59.000
# 9    2023-01-01T00:00:40.000
# 10   2023-01-01T00:15:54.000
# ..                       ...
# 995  2023-01-01T01:04:45.000
# 996  2023-01-01T01:04:46.000
# 997  2023-01-01T01:04:52.000
# 998  2023-01-01T01:04:54.000
# 999  2023-01-01T01:05:01.000
#
# [735 rows x 18 columns]

# %% [markdown]
# ## Begin EDA - Basic Questions

# %% [markdown]
# Which five cities have the highest number of 911 emergency calls?

# %%
df['boro_nm'].value_counts().head(5)
# Out:
# boro_nm
# BROOKLYN         303
# MANHATTAN        286
# BRONX            186
# QUEENS           182
# STATEN ISLAND     43
# Name: count, dtype: int64

# %% [markdown]
# What are the top 5 timeframes with the highest number of reported emergency calls?

# %%
df['incident_time'].value_counts().head(5)
# Out:
# incident_time
# 00:44:45    4
# 00:32:21    3
# 00:53:48    3
# 00:35:22    3
# 00:34:43    3
# Name: count, dtype: int64

# %% [markdown]
# In recent years, Brooklyn has consistently had the highest number of emergency calls. The busiest time for NYPD emergency responses is between 4:30 PM and 5:00 PM.

# %% [markdown]
# Now, let's examine the 'CIP JOBS' column. How many unique instances of crime in progress are there compared to non-CIP cases?

# %%
df['cip_jobs'].value_counts()
# Out:
# cip_jobs
# Non CIP         903
# Critical         55
# Non Critical     26
# Serious          16
# Name: count, dtype: int64

# %% [markdown]
# About 90 percent were flagged as Non CIP (“Non Crime in Progress”) and the largest number of calls fell under the type descriptions “See Complainant” and “Visibility Patrol.”

# %% [markdown]
# ## more analysis and visualization coming soon...
